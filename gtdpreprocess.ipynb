# %% [markdown]
# <a href="https://colab.research.google.com/github/Maha3061/Global-Terrorism-Analysis/blob/main/gtdpreprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configure notebook output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Number of rows and columns
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 150)

# %%
gtd_df = pd.read_csv('/content/drive/MyDrive/data/globalterrorism.csv', low_memory=False, index_col = 0,
                      na_values=[''],encoding='latin1')

# %%
gtd_df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 181691 entries, 197000000000.0 to 201712000000.0
# Data columns (total 134 columns):
#  #    Column              Dtype
# ---   ------              -----
#  0    iyear               int64
#  1    imonth              int64
#  2    iday                int64
#  3    approxdate          object
#  4    extended            int64
#  5    resolution          object
#  6    country             int64
#  7    country_txt         object
#  8    region              int64
#  9    region_txt          object
#  10   provstate           object
#  11   city                object
#  12   latitude            float64
#  13   longitude           float64
#  14   specificity         float64
#  15   vicinity            int64
#  16   location            object
#  17   summary             object
#  18   crit1               int64
#  19   crit2               int64
#  20   crit3               int64
#  21   doubtterr           float64
#  22   alternative         float64
#  23   alternative_txt     object
#  24   multiple            float64
#  25   success             int64
#  26   suicide             int64
#  27   attacktype1         int64
#  28   attacktype1_txt     object
#  29   attacktype2         float64
#  30   attacktype2_txt     object
#  31   attacktype3         float64
#  32   attacktype3_txt     object
#  33   targtype1           int64
#  34   targtype1_txt       object
#  35   targsubtype1        float64
#  36   targsubtype1_txt    object
#  37   corp1               object
#  38   target1             object
#  39   natlty1             float64
#  40   natlty1_txt         object
#  41   targtype2           float64
#  42   targtype2_txt       object
#  43   targsubtype2        float64
#  44   targsubtype2_txt    object
#  45   corp2               object
#  46   target2             object
#  47   natlty2             float64
#  48   natlty2_txt         object
#  49   targtype3           float64
#  50   targtype3_txt       object
#  51   targsubtype3        float64
#  52   targsubtype3_txt    object
#  53   corp3               object
#  54   target3             object
#  55   natlty3             float64
#  56   natlty3_txt         object
#  57   gname               object
#  58   gsubname            object
#  59   gname2              object
#  60   gsubname2           object
#  61   gname3              object
#  62   gsubname3           object
#  63   motive              object
#  64   guncertain1         float64
#  65   guncertain2         float64
#  66   guncertain3         float64
#  67   individual          int64
#  68   nperps              float64
#  69   nperpcap            float64
#  70   claimed             float64
#  71   claimmode           float64
#  72   claimmode_txt       object
#  73   claim2              float64
#  74   claimmode2          float64
#  75   claimmode2_txt      object
#  76   claim3              float64
#  77   claimmode3          float64
#  78   claimmode3_txt      object
#  79   compclaim           float64
#  80   weaptype1           int64
#  81   weaptype1_txt       object
#  82   weapsubtype1        float64
#  83   weapsubtype1_txt    object
#  84   weaptype2           float64
#  85   weaptype2_txt       object
#  86   weapsubtype2        float64
#  87   weapsubtype2_txt    object
#  88   weaptype3           float64
#  89   weaptype3_txt       object
#  90   weapsubtype3        float64
#  91   weapsubtype3_txt    object
#  92   weaptype4           float64
#  93   weaptype4_txt       object
#  94   weapsubtype4        float64
#  95   weapsubtype4_txt    object
#  96   weapdetail          object
#  97   nkill               float64
#  98   nkillus             float64
#  99   nkillter            float64
#  100  nwound              float64
#  101  nwoundus            float64
#  102  nwoundte            float64
#  103  property            int64
#  104  propextent          float64
#  105  propextent_txt      object
#  106  propvalue           float64
#  107  propcomment         object
#  108  ishostkid           float64
#  109  nhostkid            float64
#  110  nhostkidus          float64
#  111  nhours              float64
#  112  ndays               float64
#  113  divert              object
#  114  kidhijcountry       object
#  115  ransom              float64
#  116  ransomamt           float64
#  117  ransomamtus         float64
#  118  ransompaid          float64
#  119  ransompaidus        float64
#  120  ransomnote          object
#  121  hostkidoutcome      float64
#  122  hostkidoutcome_txt  object
#  123  nreleased           float64
#  124  addnotes            object
#  125  scite1              object
#  126  scite2              object
#  127  scite3              object
#  128  dbsource            object
#  129  INT_LOG             int64
#  130  INT_IDEO            int64
#  131  INT_MISC            int64
#  132  INT_ANY             int64
#  133  related             object
# dtypes: float64(55), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
# Check the number of missing values in each attribute
count = gtd_df.isnull().sum()
percent = round(count / 181692 * 100, 2)
series = [count, percent]
result = pd.concat(series, axis=1, keys=['Count','Percent'])
result.sort_values(by='Count', ascending=False)
# Out:
#                      Count  Percent
# gsubname3           181671    99.99
# weapsubtype4_txt    181621    99.96
# weapsubtype4        181621    99.96
# weaptype4_txt       181618    99.96
# weaptype4           181618    99.96
# claimmode3          181558    99.93
# claimmode3_txt      181558    99.93
# gsubname2           181531    99.91
# claim3              181373    99.82
# guncertain3         181371    99.82
# divert              181367    99.82
# gname3              181367    99.82
# attacktype3_txt     181263    99.76
# attacktype3         181263    99.76
# ransomnote          181177    99.72
# ransompaidus        181139    99.70
# ransomamtus         181128    99.69
# claimmode2          181075    99.66
# claimmode2_txt      181075    99.66
# ransompaid          180917    99.57
# corp3               180665    99.43
# targsubtype3        180594    99.40
# targsubtype3_txt    180594    99.40
# natlty3_txt         180544    99.37
# natlty3             180544    99.37
# target3             180516    99.35
# targtype3           180515    99.35
# targtype3_txt       180515    99.35
# ransomamt           180341    99.26
# weapsubtype3        179998    99.07
# weapsubtype3_txt    179998    99.07
# weaptype3           179828    98.97
# weaptype3_txt       179828    98.97
# claim2              179801    98.96
# guncertain2         179736    98.92
# gname2              179678    98.89
# resolution          179471    98.78
# kidhijcountry       178386    98.18
# nhours              177628    97.76
# compclaim           176852    97.34
# gsubname            175801    96.76
# attacktype2         175377    96.52
# attacktype2_txt     175377    96.52
# ndays               173567    95.53
# approxdate          172452    94.91
# corp2               171574    94.43
# nreleased           171291    94.28
# targsubtype2        171006    94.12
# targsubtype2_txt    171006    94.12
# natlty2_txt         170863    94.04
# natlty2             170863    94.04
# hostkidoutcome      170700    93.95
# hostkidoutcome_txt  170700    93.95
# target2             170671    93.93
# targtype2_txt       170547    93.87
# targtype2           170547    93.87
# weapsubtype2        170149    93.65
# weapsubtype2_txt    170149    93.65
# weaptype2           168564    92.77
# weaptype2_txt       168564    92.77
# nhostkidus          168174    92.56
# nhostkid            168119    92.53
# claimmode           162608    89.50
# claimmode_txt       162608    89.50
# related             156653    86.22
# addnotes            153402    84.43
# alternative         152680    84.03
# alternative_txt     152680    84.03
# propvalue           142702    78.54
# scite3              138175    76.05
# motive              131130    72.17
# location            126196    69.46
# propcomment         123732    68.10
# propextent          117627    64.74
# propextent_txt      117626    64.74
# scite2              104758    57.66
# ransom              104310    57.41
# nperps               71115    39.14
# nperpcap             69489    38.25
# nwoundte             69143    38.06
# weapdetail           67670    37.24
# nkillter             66958    36.85
# scite1               66191    36.43
# summary              66129    36.40
# claimed              66120    36.39
# nwoundus             64702    35.61
# nkillus              64446    35.47
# corp1                42550    23.42
# weapsubtype1         20768    11.43
# weapsubtype1_txt     20768    11.43
# nwound               16311     8.98
# targsubtype1         10373     5.71
# targsubtype1_txt     10373     5.71
# nkill                10313     5.68
# longitude             4557     2.51
# latitude              4556     2.51
# natlty1_txt           1559     0.86
# natlty1               1559     0.86
# target1                636     0.35
# city                   434     0.24
# provstate              421     0.23
# guncertain1            380     0.21
# ishostkid              178     0.10
# specificity              6     0.00
# doubtterr                1     0.00
# multiple                 1     0.00
# INT_MISC                 0     0.00
# INT_IDEO                 0     0.00
# INT_LOG                  0     0.00
# dbsource                 0     0.00
# INT_ANY                  0     0.00
# iyear                    0     0.00
# property                 0     0.00
# weaptype1_txt            0     0.00
# iday                     0     0.00
# extended                 0     0.00
# country                  0     0.00
# country_txt              0     0.00
# region                   0     0.00
# region_txt               0     0.00
# vicinity                 0     0.00
# crit1                    0     0.00
# crit2                    0     0.00
# crit3                    0     0.00
# success                  0     0.00
# suicide                  0     0.00
# attacktype1              0     0.00
# attacktype1_txt          0     0.00
# targtype1                0     0.00
# targtype1_txt            0     0.00
# gname                    0     0.00
# imonth                   0     0.00
# weaptype1                0     0.00
# individual               0     0.00

# %%
target_attrs = result[result['Percent'] < 40.0]
keep_attrs = target_attrs.index.values

# %%
keep_attrs = keep_attrs[keep_attrs != 'nperps']
keep_attrs

# Remove attributes that duplicate another attribute
keep_attrs = keep_attrs[keep_attrs != 'country']
keep_attrs = keep_attrs[keep_attrs != 'region']
keep_attrs = keep_attrs[keep_attrs != 'attacktype1']
keep_attrs = keep_attrs[keep_attrs != 'targtype1']
keep_attrs = keep_attrs[keep_attrs != 'targsubtype1']
keep_attrs = keep_attrs[keep_attrs != 'natlty1']
keep_attrs = keep_attrs[keep_attrs != 'weaptype1']
keep_attrs = keep_attrs[keep_attrs != 'weapsubtype1']
# Out:
# array(['iyear', 'imonth', 'iday', 'extended', 'country', 'country_txt',
#        'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'summary', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'gname', 'guncertain1', 'individual', 'nperpcap',
#        'claimed', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'ishostkid',
#        'scite1', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype=object)

# %%
subset_df = gtd_df.loc[:, keep_attrs]
subset_df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 181691 entries, 197000000000.0 to 201712000000.0
# Data columns (total 48 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   extended          181691 non-null  int64
#  4   country_txt       181691 non-null  object
#  5   region_txt        181691 non-null  object
#  6   provstate         181270 non-null  object
#  7   city              181257 non-null  object
#  8   latitude          177135 non-null  float64
#  9   longitude         177134 non-null  float64
#  10  specificity       181685 non-null  float64
#  11  vicinity          181691 non-null  int64
#  12  summary           115562 non-null  object
#  13  crit1             181691 non-null  int64
#  14  crit2             181691 non-null  int64
#  15  crit3             181691 non-null  int64
#  16  doubtterr         181690 non-null  float64
#  17  multiple          181690 non-null  float64
#  18  success           181691 non-null  int64
#  19  suicide           181691 non-null  int64
#  20  attacktype1_txt   181691 non-null  object
#  21  targtype1_txt     181691 non-null  object
#  22  targsubtype1_txt  171318 non-null  object
#  23  corp1             139141 non-null  object
#  24  target1           181055 non-null  object
#  25  natlty1_txt       180132 non-null  object
#  26  gname             181691 non-null  object
#  27  guncertain1       181311 non-null  float64
#  28  individual        181691 non-null  int64
#  29  nperpcap          112202 non-null  float64
#  30  claimed           115571 non-null  float64
#  31  weaptype1_txt     181691 non-null  object
#  32  weapsubtype1_txt  160923 non-null  object
#  33  weapdetail        114021 non-null  object
#  34  nkill             171378 non-null  float64
#  35  nkillus           117245 non-null  float64
#  36  nkillter          114733 non-null  float64
#  37  nwound            165380 non-null  float64
#  38  nwoundus          116989 non-null  float64
#  39  nwoundte          112548 non-null  float64
#  40  property          181691 non-null  int64
#  41  ishostkid         181513 non-null  float64
#  42  scite1            115500 non-null  object
#  43  dbsource          181691 non-null  object
#  44  INT_LOG           181691 non-null  int64
#  45  INT_IDEO          181691 non-null  int64
#  46  INT_MISC          181691 non-null  int64
#  47  INT_ANY           181691 non-null  int64
# dtypes: float64(15), int64(16), object(17)
# memory usage: 67.9+ MB

# %%
# Categorical Variables
# ---------------------
subset_df['specificity'].fillna(-1, inplace=True)

subset_df.loc[subset_df['vicinity'] == -9, 'vicinity'] = -1

subset_df.loc[subset_df['doubtterr'] == -9, 'doubtterr'] = -1

subset_df['targsubtype1_txt'].fillna('UNKNOWN', inplace=True)

subset_df['natlty1_txt'].fillna('UNKNOWN', inplace=True)

subset_df['guncertain1'].fillna(-1, inplace=True)

subset_df['claimed'].fillna(-1, inplace=True)
subset_df.loc[subset_df['claimed'] == -9, 'claimed'] = -1
subset_df['weapsubtype1_txt'].fillna('UNKNOWN', inplace=True)

subset_df.loc[subset_df['property'] == -9, 'property'] = -1

subset_df['ishostkid'].fillna(-1, inplace=True)
subset_df.loc[subset_df['ishostkid'] == -9, 'ishostkid'] = -1

subset_df.loc[subset_df['INT_LOG'] == -9, 'INT_LOG'] = -1

subset_df.loc[subset_df['INT_IDEO'] == -9, 'INT_IDEO'] = -1

subset_df.loc[subset_df['INT_MISC'] == -9, 'INT_MISC'] = -1

subset_df.loc[subset_df['INT_ANY'] == -9, 'INT_ANY'] = -1


# Numeric Variables
# -----------------
subset_df.loc[subset_df['nperpcap'] == -9, 'nperpcap'] = np.nan
subset_df.loc[subset_df['nperpcap'] == -99, 'nperpcap'] = np.nan


# Text Variables
# --------------
subset_df['provstate'].fillna('UNKNOWN', inplace=True)
subset_df['city'].fillna('UNKNOWN', inplace=True)
subset_df.loc[subset_df['city'] == 'Unknown', 'city'] = 'UNKNOWN'
subset_df['summary'].fillna('UNKNOWN', inplace=True)
subset_df['corp1'].fillna('UNKNOWN', inplace=True)
subset_df['target1'].fillna('UNKNOWN', inplace=True)
subset_df['scite1'].fillna('UNKNOWN', inplace=True)

# %%
# Map the codes to labels
ynu_map = {1: 'YES', 0: 'NO', -1: 'UKNOWN'}

# List of target attributes to map
ynu_attrs =['extended', 'vicinity', 'crit1', 'crit2', 'crit3', 'doubtterr', 'multiple',
            'success', 'suicide', 'guncertain1', 'individual', 'claimed', 'property',
            'ishostkid', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY']

# Iterate over each target attribute and map it
for att in ynu_attrs:
    att_txt = att + '_txt'
    subset_df[att_txt] = subset_df[att].map(ynu_map)

# Get the list of attributes, dropping the coded for labeled attributes
final_attrs = []

for attr in subset_df.columns.values:
    if attr not in ynu_attrs:
        final_attrs.append(attr)

subset_df2 = subset_df.loc[:, final_attrs]
subset_df2.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 181691 entries, 197000000000.0 to 201712000000.0
# Data columns (total 48 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   country_txt       181691 non-null  object
#  4   region_txt        181691 non-null  object
#  5   provstate         181691 non-null  object
#  6   city              181691 non-null  object
#  7   latitude          177135 non-null  float64
#  8   longitude         177134 non-null  float64
#  9   specificity       181691 non-null  float64
#  10  summary           181691 non-null  object
#  11  attacktype1_txt   181691 non-null  object
#  12  targtype1_txt     181691 non-null  object
#  13  targsubtype1_txt  181691 non-null  object
#  14  corp1             181691 non-null  object
#  15  target1           181691 non-null  object
#  16  natlty1_txt       181691 non-null  object
#  17  gname             181691 non-null  object
#  18  nperpcap          110336 non-null  float64
#  19  weaptype1_txt     181691 non-null  object
#  20  weapsubtype1_txt  181691 non-null  object
#  21  weapdetail        114021 non-null  object
#  22  nkill             171378 non-null  float64
#  23  nkillus           117245 non-null  float64
#  24  nkillter          114733 non-null  float64
#  25  nwound            165380 non-null  float64
#  26  nwoundus          116989 non-null  float64
#  27  nwoundte          112548 non-null  float64
#  28  scite1            181691 non-null  object
#  29  dbsource          181691 non-null  object
#  30  extended_txt      181691 non-null  object
#  31  vicinity_txt      181691 non-null  object
#  32  crit1_txt         181691 non-null  object
#  33  crit2_txt         181691 non-null  object
#  34  crit3_txt         181691 non-null  object
#  35  doubtterr_txt     181690 non-null  object
#  36  multiple_txt      181690 non-null  object
#  37  success_txt       181691 non-null  object
#  38  suicide_txt       181691 non-null  object
#  39  guncertain1_txt   181691 non-null  object
#  40  individual_txt    181691 non-null  object
#  41  claimed_txt       181691 non-null  object
#  42  property_txt      181691 non-null  object
#  43  ishostkid_txt     181691 non-null  object
#  44  INT_LOG_txt       181691 non-null  object
#  45  INT_IDEO_txt      181691 non-null  object
#  46  INT_MISC_txt      181691 non-null  object
#  47  INT_ANY_txt       181691 non-null  object
# dtypes: float64(10), int64(3), object(35)
# memory usage: 67.9+ MB

# %%
subset_df2.to_csv("/content/drive/MyDrive/data/gtdpreprocess.csv", sep = ",")
